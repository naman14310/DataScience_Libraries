# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing

tips = sns.load_dataset("tips")
flight = sns.load_dataset("flights")
iris = sns.load_dataset("iris")

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'] , kde = False , bins=10)
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(tips['total_bill'] , tips['tip'] , kind='kde' , color='red')
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.set_style(style="whitegrid")

# %%
sns.pairplot(tips , hue = 'sex')

# %%
sns.jointplot(tips['size'] , tips['tip'] , kind='scatter' , color='blue')
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.rugplot(tips['tip'])

# %%
sns.barplot(tips["sex"] , tips["total_bill"] , estimator=np.mean)

# %%
sns.countplot(tips['day'] , hue=tips['sex'])

# %%
sns.barplot(tips["smoker"] , tips["total_bill"] )

# %%
sns.boxplot(tips['day'],tips['tip'])

# %%
sns.boxplot(tips['day'],tips['total_bill'] , hue=tips['smoker'])

# %%
sns.boxplot(tips['day'],tips['total_bill'] , hue=tips['sex'])

# %%
sns.violinplot(tips['day'],tips['total_bill'] , hue=tips['smoker'])

# %%
sns.violinplot(tips['day'],tips['total_bill'] , hue=tips['smoker'] , split=True)

# %%
sns.stripplot(tips['day'],tips['total_bill'] , hue=tips['smoker'] , split=True , jitter=True)
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:2567: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style(style='ticks')

# %%
sns.swarmplot(tips['day'],tips['total_bill'] , hue=tips['smoker'])

# %%
sns.countplot(tips['sex'] , palette='deep')

# %%
sns.despine(left=False)

# %%
sns.countplot(tips['sex'] , palette='deep')

# %%
plt.figure(figsize=(200,500))

# %%
sns.countplot(tips['sex'] , palette='deep')

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.isnull())

# %%
sns.heatmap(tips.corr())

# %%
sns.heatmap(tips.corr() , cmap='coolwarm')

# %%
sns.heatmap(tips.corr() , cmap='coolwarm' , annot=True)

# %%
pt = flight.pivot_table(values="passengers" , index="month", columns="year")

# %%
sns.heatmap(pt)

# %%
sns.heatmap(pt , cmap="rainbow")

# %%
sns.heatmap(pt , cmap="magma" , linecolor="white" , linewidths='2')

# %%
sns.clustermap(pt , cmap = "coolwarm")

# %%
sns.clustermap(pt , cmap = "coolwarm"  , standard_scale='1')

# %%
sns.lmplot(x='total_bill' , y='tip' , data=tips , hue="sex")

# %%
sns.lmplot(x='total_bill' , y='tip' , data=tips , hue="smoker")

# %%
sns.jointplot(x='total_bill' , y='tip' ,data=tips, kind="reg" )
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/lenovo/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.lmplot(x='total_bill' , y='tip' , data=tips , row="sex" , col="time" , hue="smoker")

# %%
sns.lmplot(x='total_bill' , y='tip' , data=tips , col="day" , hue="smoker" , aspect=1 , size=8)

# %%
pg=sns.PairGrid(iris)
pg.map(plt.scatter)

# %%
pg=sns.PairGrid(iris)
pg.map(plt.scatter)

# %%
pg=sns.PairGrid(iris)
pg.map_upper(sns.kdeplot)
pg.map_diag(plt.hist)
pg.map_lower(plt.scatter)
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
sns.pairplot(iris , hue="species")

# %%
sns.countplot(x='smoker', data=tips , hue="time")
