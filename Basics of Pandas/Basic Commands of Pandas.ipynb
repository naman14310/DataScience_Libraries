# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
os.chdir('/home/lenovo/data_files')

# %%
# getting data from csv file
df = pd.read_csv('baseball.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0     ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 1     ATL     NL  2012  700  600   94  0.320  0.389  0.247         1
# 2     BAL     AL  2012  712  705   93  0.311  0.417  0.247         1
# 3     BOS     AL  2012  734  806   69  0.315  0.415  0.260         0
# 4     CHC     NL  2012  613  759   61  0.302  0.378  0.240         0
# 5     CHW     AL  2012  748  676   85  0.318  0.422  0.255         0
# 6     CIN     NL  2012  669  588   97  0.315  0.411  0.251         1
# 7     CLE     AL  2012  667  845   68  0.324  0.381  0.251         0
# 8     COL     NL  2012  758  890   64  0.330  0.436  0.274         0
# 9     DET     AL  2012  726  670   88  0.335  0.422  0.268         1
# 10    HOU     NL  2012  583  794   55  0.302  0.371  0.236         0
# 11    KCR     AL  2012  676  746   72  0.317  0.400  0.265         0
# ...

# %%
df.tail(5)
# Out:
#      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 1227  PHI     NL  1962  705  759   81  0.330  0.390  0.260         0
# 1228  PIT     NL  1962  706  626   93  0.321  0.394  0.268         0
# 1229  SFG     NL  1962  878  690  103  0.341  0.441  0.278         1
# 1230  STL     NL  1962  774  664   84  0.335  0.394  0.271         0
# 1231  WSA     AL  1962  599  716   60  0.308  0.373  0.250         0
#
#       RankSeason  RankPlayoffs    G  OOBP  OSLG
# 1227         NaN           NaN  161   NaN   NaN
# 1228         NaN           NaN  161   NaN   NaN
# 1229         1.0           2.0  165   NaN   NaN
# 1230         NaN           NaN  163   NaN   NaN
# 1231         NaN           NaN  162   NaN   NaN

# %%
#getting dimensions
df.shape
# Out:
# (1232, 15)

# %%
print(df.shape)
# Out:
# (1232, 15)

# %%
#getting names of column
df.columns.values
# Out:
# array(['Team', 'League', 'Year', 'RS', 'RA', 'W', 'OBP', 'SLG', 'BA',
#        'Playoffs', 'RankSeason', 'RankPlayoffs', 'G', 'OOBP', 'OSLG'], dtype=object)

# %%
df.columns.names
# Out:
# FrozenList([None])

# %%
# add column to dataframe
df['jersy no']='10'

# %%
df
# Out:
#      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0     ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 1     ATL     NL  2012  700  600   94  0.320  0.389  0.247         1
# 2     BAL     AL  2012  712  705   93  0.311  0.417  0.247         1
# 3     BOS     AL  2012  734  806   69  0.315  0.415  0.260         0
# 4     CHC     NL  2012  613  759   61  0.302  0.378  0.240         0
# 5     CHW     AL  2012  748  676   85  0.318  0.422  0.255         0
# 6     CIN     NL  2012  669  588   97  0.315  0.411  0.251         1
# 7     CLE     AL  2012  667  845   68  0.324  0.381  0.251         0
# 8     COL     NL  2012  758  890   64  0.330  0.436  0.274         0
# 9     DET     AL  2012  726  670   88  0.335  0.422  0.268         1
# 10    HOU     NL  2012  583  794   55  0.302  0.371  0.236         0
# 11    KCR     AL  2012  676  746   72  0.317  0.400  0.265         0
# 12    LAA     AL  2012  767  699   89  0.332  0.433  0.274         0
# ...

# %%
#renaming column name
df.rename(columns={'Team':'Team-name'})
# Out:
#      Team-name League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0          ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 1          ATL     NL  2012  700  600   94  0.320  0.389  0.247         1
# 2          BAL     AL  2012  712  705   93  0.311  0.417  0.247         1
# 3          BOS     AL  2012  734  806   69  0.315  0.415  0.260         0
# 4          CHC     NL  2012  613  759   61  0.302  0.378  0.240         0
# 5          CHW     AL  2012  748  676   85  0.318  0.422  0.255         0
# 6          CIN     NL  2012  669  588   97  0.315  0.411  0.251         1
# 7          CLE     AL  2012  667  845   68  0.324  0.381  0.251         0
# 8          COL     NL  2012  758  890   64  0.330  0.436  0.274         0
# 9          DET     AL  2012  726  670   88  0.335  0.422  0.268         1
# 10         HOU     NL  2012  583  794   55  0.302  0.371  0.236         0
# 11         KCR     AL  2012  676  746   72  0.317  0.400  0.265         0
# ...

# %%
#deleting a row
df.drop([1,2,3] )
# Out:
#      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0     ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 4     CHC     NL  2012  613  759   61  0.302  0.378  0.240         0
# 5     CHW     AL  2012  748  676   85  0.318  0.422  0.255         0
# 6     CIN     NL  2012  669  588   97  0.315  0.411  0.251         1
# 7     CLE     AL  2012  667  845   68  0.324  0.381  0.251         0
# 8     COL     NL  2012  758  890   64  0.330  0.436  0.274         0
# 9     DET     AL  2012  726  670   88  0.335  0.422  0.268         1
# 10    HOU     NL  2012  583  794   55  0.302  0.371  0.236         0
# 11    KCR     AL  2012  676  746   72  0.317  0.400  0.265         0
# 12    LAA     AL  2012  767  699   89  0.332  0.433  0.274         0
# 13    LAD     NL  2012  637  597   86  0.317  0.374  0.252         0
# 14    MIA     NL  2012  609  724   69  0.308  0.382  0.244         0
# 15    MIL     NL  2012  776  733   83  0.325  0.437  0.259         0
# ...

# %%
#printing true if there is NAN in any column
df.isna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d9a2e5f1cfd5> in <module>()
#       1 #printing true if there is NAN in any column
# ----> 2 df.isna()
#
# /home/lenovo/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
df.isnull().any(axis=1)

# %%
#printing summary
df.describe

# %%
#sorting dataframes with respect to values of a particular column
df.sort_values('OOBP')
# Out:
#      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 26    TBR     AL  2012  697  577   90  0.317  0.394  0.240         0
# 50    PHI     NL  2011  713  529  102  0.323  0.395  0.253         1
# 354   SEA     AL  2001  927  627  116  0.360  0.445  0.288         1
# 217   CLE     AL  2005  790  642   93  0.334  0.453  0.271         0
# 56    TBR     AL  2011  707  614   91  0.322  0.402  0.244         1
# 29    WSN     NL  2012  731  594   98  0.322  0.428  0.261         1
# 45    MIL     NL  2011  721  638   96  0.325  0.425  0.261         1
# 301   ARI     NL  2002  819  674   98  0.346  0.423  0.267         1
# 6     CIN     NL  2012  669  588   97  0.315  0.411  0.251         1
# 19    OAK     AL  2012  713  614   94  0.310  0.404  0.238         1
# 284   LAD     NL  2003  574  556   85  0.303  0.368  0.243         0
# 20    PHI     NL  2012  684  680   81  0.317  0.400  0.255         0
# 1     ATL     NL  2012  700  600   94  0.320  0.389  0.247         1
# ...

# %%
#replacing NAN with some default value
df.replace(np.nan,'not applicable',regex=True)
# Out:
#      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0     ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 1     ATL     NL  2012  700  600   94  0.320  0.389  0.247         1
# 2     BAL     AL  2012  712  705   93  0.311  0.417  0.247         1
# 3     BOS     AL  2012  734  806   69  0.315  0.415  0.260         0
# 4     CHC     NL  2012  613  759   61  0.302  0.378  0.240         0
# 5     CHW     AL  2012  748  676   85  0.318  0.422  0.255         0
# 6     CIN     NL  2012  669  588   97  0.315  0.411  0.251         1
# 7     CLE     AL  2012  667  845   68  0.324  0.381  0.251         0
# 8     COL     NL  2012  758  890   64  0.330  0.436  0.274         0
# 9     DET     AL  2012  726  670   88  0.335  0.422  0.268         1
# 10    HOU     NL  2012  583  794   55  0.302  0.371  0.236         0
# 11    KCR     AL  2012  676  746   72  0.317  0.400  0.265         0
# 12    LAA     AL  2012  767  699   89  0.332  0.433  0.274         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 16 columns):
# Team            1232 non-null object
# League          1232 non-null object
# Year            1232 non-null int64
# RS              1232 non-null int64
# RA              1232 non-null int64
# W               1232 non-null int64
# OBP             1232 non-null float64
# SLG             1232 non-null float64
# BA              1232 non-null float64
# Playoffs        1232 non-null int64
# RankSeason      244 non-null float64
# RankPlayoffs    244 non-null float64
# G               1232 non-null int64
# OOBP            420 non-null float64
# OSLG            420 non-null float64
# jersy no        1232 non-null object
# dtypes: float64(7), int64(6), object(3)
# memory usage: 154.1+ KB

# %%
 t=df['RS']> 650

# %%
df[t]
# Out:
#      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0     ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 1     ATL     NL  2012  700  600   94  0.320  0.389  0.247         1
# 2     BAL     AL  2012  712  705   93  0.311  0.417  0.247         1
# 3     BOS     AL  2012  734  806   69  0.315  0.415  0.260         0
# 5     CHW     AL  2012  748  676   85  0.318  0.422  0.255         0
# 6     CIN     NL  2012  669  588   97  0.315  0.411  0.251         1
# 7     CLE     AL  2012  667  845   68  0.324  0.381  0.251         0
# 8     COL     NL  2012  758  890   64  0.330  0.436  0.274         0
# 9     DET     AL  2012  726  670   88  0.335  0.422  0.268         1
# 11    KCR     AL  2012  676  746   72  0.317  0.400  0.265         0
# 12    LAA     AL  2012  767  699   89  0.332  0.433  0.274         0
# 15    MIL     NL  2012  776  733   83  0.325  0.437  0.259         0
# 16    MIN     AL  2012  701  832   66  0.325  0.390  0.260         0
# ...
